# %%
import pandas as pd
import numpy as np
import os

# %%
dosya_yolu = os.path.join("data-science-projects", "churn-bigml-20.csv")
try:
    df = pd.read_csv(dosya_yolu)
    print("✅ Veri seti başarıyla yüklendi.")
except Exception as e:
    print(f"❌ Veri yüklenirken bir hata oluştu: {e}")
# Out:
# ❌ Veri yüklenirken bir hata oluştu: [Errno 2] No such file or directory: 'data-science-projects/churn-bigml-20.csv'
